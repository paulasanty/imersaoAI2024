# %% [markdown]
# <a href="https://colab.research.google.com/github/paulasanty/imersaoAI2024/blob/main/doa%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the Python SDK
import google.generativeai as genai
import pandas as pd
import numpy as np
import textwrap
from IPython.display import display
from IPython.display import Markdown
import PIL.Image
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
item1 = {
    "Tipo": "Alimento",
    "DescriçãoItem": "Arroz",
    "Quantidade": "2 kg",
    "Vencimento": "20/03/2024",
    "TipoAcesso": "terreste",
    "Endereço": "Rua A, 123 - Centro",
}
item2 = {
    "Tipo": "Higiene",
    "DescriçãoItem": "Sabonete Líquido",
    "Quantidade": "3 unidades",
    "Vencimento": "15/12/2025",
    "TipoAcesso": "Aereo",
    "Endereço": "Av. B, 456 - Jardins",
}
item3 = {
    "Tipo": "Alimento",
    "DescriçãoItem": "Feijão ",
    "Quantidade": "1 kg",
    "Vencimento": "15/12/2025",
    "TipoAcesso": "Terreste",
    "Endereço": "Rua C, 789 - Vila Maria",
}

lista = [item1, item2, item3]

# %%
df = pd.DataFrame(lista)
df.columns = ["Tipo", "DescriçãoItem","Quantidade", "Vencimento","TipoAcesso", "Endereço"]
df
# Out:
#        Tipo     DescriçãoItem  Quantidade  Vencimento TipoAcesso  \
# 0  Alimento             Arroz        2 kg  20/03/2024   terreste
# 1   Higiene  Sabonete Líquido  3 unidades  15/12/2025      Aereo
# 2  Alimento           Feijão         1 kg  15/12/2025   Terreste
#
#                   Endereço
# 0      Rua A, 123 - Centro
# 1     Av. B, 456 - Jardins
# 2  Rua C, 789 - Vila Maria

# %%
morador1 = {
    "Idade": "07",
    "Genero": "feminino",
    "Local": "Av. B, 456 - Jardins",
    "tipoLocal": "Abrigo",
    "TipoAcesso": "terrestre"
}
morador2 = {
    "Idade": "77",
    "Genero": "masculino",
    "Local": "Rua A, 123 - Centro",
    "tipoLocal": "Abrigo",
    "TipoAcesso": "terrestre"
}
morador3 = {
    "Idade": "30",
    "Genero": "feminino",
    "Local": "aereo",
    "tipoLocal": "Abrigo",
    "TipoAcesso": "terrestre"
}

listaMorador = [morador1, morador1, morador1]

# %%
df = pd.DataFrame(listaMorador)
df.columns = ["Idade", "Genero","Local", "tipoLocal","TipoAcesso"]
df
# Out:
#   Idade    Genero                 Local tipoLocal TipoAcesso
# 0    07  feminino  Av. B, 456 - Jardins    Abrigo  terrestre
# 1    07  feminino  Av. B, 456 - Jardins    Abrigo  terrestre
# 2    07  feminino  Av. B, 456 - Jardins    Abrigo  terrestre

# %%
config = { "candidate_count": 1, "temperature": 0.5 }

# %%
settings = {
   "HARASSMENT": "BLOCK_NONE",
    "HATE": "BLOCK_NONE",
    "SEXUAL": "BLOCK_NONE",
    "DANGEROUS": "BLOCK_NONE"
}

# %%
prompt = f"Há itens disponivel para regição proxino a Rua A: {df.Endereço}"

model_2 =  genai.GenerativeModel("gemini-1.0-pro",generation_config=config)
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# Sim, há 1 item disponível para a região próxima à Rua A:
#
# * Rua A, 123 - Centro
